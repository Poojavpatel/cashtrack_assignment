# %%
import pandas as pd
df =pd.read_csv("dataoutput.csv")
df
# Out:
#                                                   name  \
# 0                                  Achilles Tendonitis
# 1                                        Acne Vulgaris
# 2                                   Acute Appendicitis
# 3    Acute Aspiration of Oropharyngeal or Gastric C...
# 4                                     Acute Bronchitis
# 5                                      Acute Gastritis
# 6                                  Acute HIV Infection
# 7                                  Acute Heart Failure
# 8                                     Acute Laryngitis
# 9                                   Acute Otitis Media
# 10                                  Acute Pancreatitis
# 11                                  Acute Panic Attack
# 12                                   Acute Pharyngitis
# 13                                Acute Pyelonephritis
# 14                               Acute Stress Disorder
# 15                              Acute Varicella Zoster
# ...

# %%
df.columns
# Out:
# Index(['name', 'link'], dtype='object')
